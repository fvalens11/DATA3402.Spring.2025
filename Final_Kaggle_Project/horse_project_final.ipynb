# %%
import pandas as pd
import numpy as np
import matplotlib as plt

df = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#      id surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0  1235      no  adult           534053         38.6   40.0              20.0
# 1  1236     yes  adult           528469         38.2  112.0              48.0
# 2  1237     yes  adult           528178         37.7   66.0              12.0
# 3  1238      no  adult           534784         37.1   88.0              20.0
# 4  1239     yes  adult           529840         38.3   50.0              12.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane  ...        abdomen  \
# 0              normal           normal     normal_pink  ...  distend_small
# 1                cool          reduced     bright_pink  ...  distend_small
# 2                cool           normal      bright_red  ...  distend_small
# 3                cool          reduced   pale_cyanotic  ...  distend_large
# 4                 NaN           normal     bright_pink  ...  distend_small
#
#   packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0               42.0           7.5             clear            2.3
# 1               44.0           6.0     serosanguious            2.6
# 2               31.5           6.0            cloudy            1.6
# 3               75.0          81.0               NaN            1.0
# 4               37.0           6.8            cloudy            2.6
#
#   surgical_lesion  lesion_1 lesion_2 lesion_3  cp_data
# 0              no         0        0        0       no
# 1              no      2208        0        0      yes
# 2             yes      2205        0        0      yes
# 3             yes      1400        0        0       no
# 4             yes      2208        0        0      yes
#
# [5 rows x 28 columns]

# %%
df.describe()
# Out:
#                 id  hospital_number  rectal_temp       pulse  \
# count   824.000000     8.240000e+02   824.000000  824.000000
# mean   1646.500000     1.108357e+06    38.244539   80.229369
# std     238.012605     1.555627e+06     0.785234   29.164711
# min    1235.000000     5.213990e+05    36.000000   36.000000
# 25%    1440.750000     5.287430e+05    37.800000   54.000000
# 50%    1646.500000     5.298085e+05    38.200000   76.000000
# 75%    1852.250000     5.346440e+05    38.600000  100.000000
# max    2058.000000     5.305129e+06    40.800000  184.000000
#
#        respiratory_rate  nasogastric_reflux_ph  packed_cell_volume  \
# count         824.00000             824.000000          824.000000
# mean           30.71966               4.508495           49.063350
# std            17.43191               1.883464           10.450138
# min             9.00000               1.000000           23.000000
# 25%            18.00000               3.000000           43.000000
# 50%            28.00000               4.500000           48.000000
# 75%            36.00000               6.500000           55.000000
# max            96.00000               7.500000           75.000000
#
#        total_protein  abdomo_protein      lesion_1     lesion_2  lesion_3
# count     824.000000      824.000000    824.000000   824.000000     824.0
# mean       20.796238        3.336420   3709.803398    12.391990       0.0
# std        26.413588        1.539235   5112.931057   197.067771       0.0
# min         3.900000        0.100000      0.000000     0.000000       0.0
# 25%         6.600000        2.000000   2205.000000     0.000000       0.0
# 50%         7.500000        3.300000   2209.000000     0.000000       0.0
# 75%         8.900000        4.300000   3205.000000     0.000000       0.0
# max        89.000000       10.100000  31110.000000  4300.000000       0.0

# %%
df.isnull()
# Out:
#         id  surgery    age  hospital_number  rectal_temp  pulse  \
# 0    False    False  False            False        False  False
# 1    False    False  False            False        False  False
# 2    False    False  False            False        False  False
# 3    False    False  False            False        False  False
# 4    False    False  False            False        False  False
# ..     ...      ...    ...              ...          ...    ...
# 819  False    False  False            False        False  False
# 820  False    False  False            False        False  False
# 821  False    False  False            False        False  False
# 822  False    False  False            False        False  False
# 823  False    False  False            False        False  False
#
#      respiratory_rate  temp_of_extremities  peripheral_pulse  mucous_membrane  \
# 0               False                False             False            False
# 1               False                False             False            False
# 2               False                False             False            False
# 3               False                False             False            False
# 4               False                 True             False            False
# ..                ...                  ...               ...              ...
# 819             False                False             False            False
# 820             False                False             False            False
# 821             False                False             False            False
# 822             False                False             False            False
# 823             False                False             False            False
#
#      ...  abdomen  packed_cell_volume  total_protein  abdomo_appearance  \
# 0    ...    False               False          False              False
# 1    ...    False               False          False              False
# 2    ...    False               False          False              False
# 3    ...    False               False          False               True
# 4    ...    False               False          False              False
# ..   ...      ...                 ...            ...                ...
# 819  ...    False               False          False              False
# 820  ...    False               False          False              False
# 821  ...     True               False          False              False
# 822  ...     True               False          False              False
# 823  ...    False               False          False               True
#
#      abdomo_protein  surgical_lesion  lesion_1  lesion_2  lesion_3  cp_data
# 0             False            False     False     False     False    False
# 1             False            False     False     False     False    False
# 2             False            False     False     False     False    False
# 3             False            False     False     False     False    False
# 4             False            False     False     False     False    False
# ..              ...              ...       ...       ...       ...      ...
# 819           False            False     False     False     False    False
# 820           False            False     False     False     False    False
# 821           False            False     False     False     False    False
# 822           False            False     False     False     False    False
# 823           False            False     False     False     False    False
#
# [824 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# id                         0
# surgery                    0
# age                        0
# hospital_number            0
# rectal_temp                0
# pulse                      0
# respiratory_rate           0
# temp_of_extremities       35
# peripheral_pulse          47
# mucous_membrane           13
# capillary_refill_time      6
# pain                      29
# peristalsis               19
# abdominal_distention      22
# nasogastric_tube          64
# nasogastric_reflux        14
# nasogastric_reflux_ph      0
# rectal_exam_feces        125
# abdomen                  154
# packed_cell_volume         0
# total_protein              0
# abdomo_appearance         31
# abdomo_protein             0
# surgical_lesion            0
# lesion_1                   0
# lesion_2                   0
# lesion_3                   0
# cp_data                    0
# dtype: int64

# %%
df_tr.isnull().sum()
# Out:
# id                         0
# surgery                    0
# age                        0
# hospital_number            0
# rectal_temp                0
# pulse                      0
# respiratory_rate           0
# temp_of_extremities       39
# peripheral_pulse          60
# mucous_membrane           21
# capillary_refill_time      6
# pain                      44
# peristalsis               20
# abdominal_distention      23
# nasogastric_tube          80
# nasogastric_reflux        21
# nasogastric_reflux_ph      0
# rectal_exam_feces        190
# abdomen                  213
# packed_cell_volume         0
# total_protein              0
# abdomo_appearance         48
# abdomo_protein             0
# surgical_lesion            0
# lesion_1                   0
# lesion_2                   0
# lesion_3                   0
# cp_data                    0
# outcome                    0
# dtype: int64

# %%
np.any(df.isnull())
# Out:
# True

# %%
df.shape
# Out:
# (824, 28)

# %%
df.head()
# Out:
#      id surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0  1235      no  adult           534053         38.6   40.0              20.0
# 1  1236     yes  adult           528469         38.2  112.0              48.0
# 2  1237     yes  adult           528178         37.7   66.0              12.0
# 3  1238      no  adult           534784         37.1   88.0              20.0
# 4  1239     yes  adult           529840         38.3   50.0              12.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane  ...        abdomen  \
# 0              normal           normal     normal_pink  ...  distend_small
# 1                cool          reduced     bright_pink  ...  distend_small
# 2                cool           normal      bright_red  ...  distend_small
# 3                cool          reduced   pale_cyanotic  ...  distend_large
# 4                 NaN           normal     bright_pink  ...  distend_small
#
#   packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0               42.0           7.5             clear            2.3
# 1               44.0           6.0     serosanguious            2.6
# 2               31.5           6.0            cloudy            1.6
# 3               75.0          81.0               NaN            1.0
# 4               37.0           6.8            cloudy            2.6
#
#   surgical_lesion  lesion_1 lesion_2 lesion_3  cp_data
# 0              no         0        0        0       no
# 1              no      2208        0        0      yes
# 2             yes      2205        0        0      yes
# 3             yes      1400        0        0       no
# 4             yes      2208        0        0      yes
#
# [5 rows x 28 columns]

# %%
df_tr=pd.read_csv('train.csv')

df_tr.head()
# Out:
#    id surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0   0     yes  adult           530001         38.1  132.0              24.0
# 1   1     yes  adult           533836         37.5   88.0              12.0
# 2   2     yes  adult           529812         38.3  120.0              28.0
# 3   3     yes  adult          5262541         37.1   72.0              30.0
# 4   4      no  adult          5299629         38.0   52.0              48.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane  ...  \
# 0                cool          reduced   dark_cyanotic  ...
# 1                cool           normal   pale_cyanotic  ...
# 2                cool          reduced       pale_pink  ...
# 3                cold          reduced       pale_pink  ...
# 4              normal           normal     normal_pink  ...
#
#   packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0               57.0           8.5     serosanguious            3.4
# 1               33.0          64.0     serosanguious            2.0
# 2               37.0           6.4     serosanguious            3.4
# 3               53.0           7.0            cloudy            3.9
# 4               47.0           7.3            cloudy            2.6
#
#   surgical_lesion lesion_1  lesion_2 lesion_3 cp_data     outcome
# 0             yes     2209         0        0      no        died
# 1             yes     2208         0        0      no  euthanized
# 2             yes     5124         0        0      no       lived
# 3             yes     2208         0        0     yes       lived
# 4              no        0         0        0     yes       lived
#
# [5 rows x 29 columns]

# %%
df_tr.describe()
# Out:
#               id  hospital_number  rectal_temp        pulse  respiratory_rate  \
# count  1235.0000     1.235000e+03  1235.000000  1235.000000       1235.000000
# mean    617.0000     9.545004e+05    38.202186    79.574089         30.054251
# std     356.6581     1.356403e+06     0.788668    29.108638         16.452066
# min       0.0000     5.213990e+05    35.400000    30.000000          8.000000
# 25%     308.5000     5.288000e+05    37.800000    53.000000         18.000000
# 50%     617.0000     5.297770e+05    38.200000    76.000000         28.000000
# 75%     925.5000     5.341450e+05    38.600000   100.000000         36.000000
# max    1234.0000     5.305129e+06    40.800000   184.000000         96.000000
#
#        nasogastric_reflux_ph  packed_cell_volume  total_protein  \
# count            1235.000000         1235.000000    1235.000000
# mean                4.382591           49.602429      21.388016
# std                 1.937357           10.535800      26.676453
# min                 1.000000           23.000000       3.500000
# 25%                 2.000000           43.000000       6.600000
# 50%                 4.500000           48.000000       7.500000
# 75%                 6.000000           57.000000       9.100000
# max                 7.500000           75.000000      89.000000
#
#        abdomo_protein      lesion_1     lesion_2     lesion_3
# count     1235.000000   1235.000000  1235.000000  1235.000000
# mean         3.290931   3832.496356    14.612146     3.577328
# std          1.589195   5436.733774   193.705735    88.858953
# min          0.100000      0.000000     0.000000     0.000000
# 25%          2.000000   2205.000000     0.000000     0.000000
# 50%          3.000000   2209.000000     0.000000     0.000000
# 75%          4.300000   3205.000000     0.000000     0.000000
# max         10.100000  41110.000000  3112.000000  2209.000000

# %%
train = df_tr
test = df

# %%
print("Columns in train:", train.columns.tolist())

if 'outcome' in train.columns:
    train_features = train.drop(columns=['outcome'])
else:
    train_features = train.copy()

int_columns = train_features.select_dtypes(include=['int', 'int32', 'int64']).columns

num_features = len(int_columns)
cols = 2
rows = (num_features + cols - 1) // cols

plt.figure(figsize=(14, 4 * rows))

for i, col in enumerate(int_columns, 1):
    plt.subplot(rows, cols, i)

    if col in test.columns:
        train_vals = train[col].dropna()
        test_vals = test[col].dropna()

        plt.hist(train_vals, bins=30, alpha=0.5, color='blue', label='Train', density=True)
        plt.hist(test_vals, bins=30, alpha=0.5, color='red', label='Test', density=True)
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Density')
        plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Columns in train: ['id', 'surgery', 'age', 'hospital_number', 'rectal_temp', 'pulse', 'respiratory_rate', 'temp_of_extremities', 'peripheral_pulse', 'mucous_membrane', 'capillary_refill_time', 'pain', 'peristalsis', 'abdominal_distention', 'nasogastric_tube', 'nasogastric_reflux', 'nasogastric_reflux_ph', 'rectal_exam_feces', 'abdomen', 'packed_cell_volume', 'total_protein', 'abdomo_appearance', 'abdomo_protein', 'surgical_lesion', 'lesion_1', 'lesion_2', 'lesion_3', 'cp_data']

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# id                       0
# surgery                  0
# age                      0
# hospital_number          0
# rectal_temp              0
# pulse                    0
# respiratory_rate         0
# temp_of_extremities      0
# peripheral_pulse         0
# mucous_membrane          0
# capillary_refill_time    0
# pain                     0
# peristalsis              0
# abdominal_distention     0
# nasogastric_tube         0
# nasogastric_reflux       0
# nasogastric_reflux_ph    0
# rectal_exam_feces        0
# abdomen                  0
# packed_cell_volume       0
# total_protein            0
# abdomo_appearance        0
# abdomo_protein           0
# surgical_lesion          0
# lesion_1                 0
# lesion_2                 0
# lesion_3                 0
# cp_data                  0
# dtype: int64

# %%
df_tr = df_tr.dropna()

# %%
df_tr.isnull().sum()
# Out:
# id                       0
# surgery                  0
# age                      0
# hospital_number          0
# rectal_temp              0
# pulse                    0
# respiratory_rate         0
# temp_of_extremities      0
# peripheral_pulse         0
# mucous_membrane          0
# capillary_refill_time    0
# pain                     0
# peristalsis              0
# abdominal_distention     0
# nasogastric_tube         0
# nasogastric_reflux       0
# nasogastric_reflux_ph    0
# rectal_exam_feces        0
# abdomen                  0
# packed_cell_volume       0
# total_protein            0
# abdomo_appearance        0
# abdomo_protein           0
# surgical_lesion          0
# lesion_1                 0
# lesion_2                 0
# lesion_3                 0
# cp_data                  0
# outcome                  0
# dtype: int64

# %%
Train = df_tr

# %%
Test = df

# %%
Train['surgery'].replace(['yes','no'],[1,0],inplace=True)
Train['temp_of_extremities'].replace(['cold','cool','normal','warm'],[0,1,2,3],inplace=True)
Train['peripheral_pulse'].replace(['absent','reduced','normal','increased'],[0,1,2,3],inplace=True)
Train['capillary_refill_time'].replace(['less_3_sec','3','more_3_sec'],[0,1,2],inplace=True)
Train['pain'].replace(['mild_pain','alert','extreme_pain','severe_pain','depressed'],[0,1,2,3,4],inplace=True)
Train['peristalsis'].replace(['absent','normal','hypomotile','hypermotile'],[0,1,2,3],inplace=True)
Train['abdominal_distention'].replace(['none','slight','moderate','severe'],[0,1,2,3],inplace=True)
Train['nasogastric_tube'].replace(['none','slight','significant'],[0,1,2],inplace=True)
Train['nasogastric_reflux'].replace(['none','slight','less_1_liter','more_1_liter'],[0,1,2,3],inplace=True)
Train['rectal_exam_feces'].replace(['absent','normal','decreased','increased','serosanguious'],[0,1,2,3,4],inplace=True)
Train['abdomen'].replace(['normal','firm','distend_small','distend_large','other'],[0,1,2,3,4],inplace=True)
Train['abdomo_appearance'].replace(['clear','cloudy','serosanguious'],[0,1,2],inplace=True)
Train['surgical_lesion'].replace(['no','yes'],[0,1],inplace=True)
Train['cp_data'].replace(['no','yes'],[0,1],inplace=True)
Train['outcome'].replace(['died','lived','euthanized'],[0,1,2],inplace=True)
# Out:
# /tmp/ipykernel_444/3812164968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['surgery'].replace(['yes','no'],[1,0],inplace=True)
# /tmp/ipykernel_444/3812164968.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['temp_of_extremities'].replace(['cold','cool','normal','warm'],[0,1,2,3],inplace=True)
# /tmp/ipykernel_444/3812164968.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['peripheral_pulse'].replace(['absent','reduced','normal','increased'],[0,1,2,3],inplace=True)
# /tmp/ipykernel_444/3812164968.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['capillary_refill_time'].replace(['less_3_sec','3','more_3_sec'],[0,1,2],inplace=True)
# /tmp/ipykernel_444/3812164968.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['pain'].replace(['mild_pain','alert','extreme_pain','severe_pain','depressed'],[0,1,2,3,4],inplace=True)
# /tmp/ipykernel_444/3812164968.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['peristalsis'].replace(['absent','normal','hypomotile','hypermotile'],[0,1,2,3],inplace=True)
# /tmp/ipykernel_444/3812164968.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['abdominal_distention'].replace(['none','slight','moderate','severe'],[0,1,2,3],inplace=True)
# /tmp/ipykernel_444/3812164968.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['nasogastric_tube'].replace(['none','slight','significant'],[0,1,2],inplace=True)
# /tmp/ipykernel_444/3812164968.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['nasogastric_reflux'].replace(['none','slight','less_1_liter','more_1_liter'],[0,1,2,3],inplace=True)
# /tmp/ipykernel_444/3812164968.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['rectal_exam_feces'].replace(['absent','normal','decreased','increased','serosanguious'],[0,1,2,3,4],inplace=True)
# /tmp/ipykernel_444/3812164968.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['abdomen'].replace(['normal','firm','distend_small','distend_large','other'],[0,1,2,3,4],inplace=True)
# /tmp/ipykernel_444/3812164968.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['abdomo_appearance'].replace(['clear','cloudy','serosanguious'],[0,1,2],inplace=True)
# /tmp/ipykernel_444/3812164968.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['surgical_lesion'].replace(['no','yes'],[0,1],inplace=True)
# /tmp/ipykernel_444/3812164968.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['cp_data'].replace(['no','yes'],[0,1],inplace=True)
# /tmp/ipykernel_444/3812164968.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['outcome'].replace(['died','lived','euthanized'],[0,1,2],inplace=True)

# %%
Train.head()
# Out:
#    id  surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0   0        1  adult           530001         38.1  132.0              24.0
# 1   1        1  adult           533836         37.5   88.0              12.0
# 3   3        1  adult          5262541         37.1   72.0              30.0
# 4   4        0  adult          5299629         38.0   52.0              48.0
# 5   5        0  adult           529642         38.1   56.0              32.0
#
#    temp_of_extremities  peripheral_pulse mucous_membrane  ...  \
# 0                    1                 1   dark_cyanotic  ...
# 1                    1                 2   pale_cyanotic  ...
# 3                    0                 1       pale_pink  ...
# 4                    2                 2     normal_pink  ...
# 5                    2                 2     bright_pink  ...
#
#    packed_cell_volume  total_protein  abdomo_appearance  abdomo_protein  \
# 0                57.0            8.5                  2             3.4
# 1                33.0           64.0                  2             2.0
# 3                53.0            7.0                  1             3.9
# 4                47.0            7.3                  1             2.6
# 5                49.0            8.0                  1             2.8
#
#    surgical_lesion  lesion_1  lesion_2  lesion_3  cp_data  outcome
# 0                1      2209         0         0        0        0
# 1                1      2208         0         0        0        2
# 3                1      2208         0         0        1        1
# 4                0         0         0         0        1        1
# 5                0         0         0         0        1        1
#
# [5 rows x 29 columns]

# %%
Train['mucous_membrane'].replace(['normal_pink','pale_pink','bright_pink','bright_red','pale_cyanotic','dark_cyanotic'],[0,1,2,3,4,5],inplace=True)
# Out:
# /tmp/ipykernel_444/4262568179.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['mucous_membrane'].replace(['normal_pink','pale_pink','bright_pink','bright_red','pale_cyanotic','dark_cyanotic'],[0,1,2,3,4,5],inplace=True)

# %%
Train['age'].replace(['adult','young'],[1,0],inplace=True)
# Out:
# /tmp/ipykernel_444/2618284777.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['age'].replace(['adult','young'],[1,0],inplace=True)

# %%
Train = Train.drop(columns=['hospital_number'])

# %%
Test['surgery'].replace(['yes','no'],[1,0],inplace=True)
Test['temp_of_extremities'].replace(['cold','cool','normal','warm'],[0,1,2,3],inplace=True)
Test['peripheral_pulse'].replace(['absent','reduced','normal','increased'],[0,1,2,3],inplace=True)
Test['capillary_refill_time'].replace(['less_3_sec','3','more_3_sec'],[0,1,2],inplace=True)
Test['pain'].replace(['mild_pain','alert','extreme_pain','severe_pain','depressed'],[0,1,2,3,4],inplace=True)
Test['mucous_membrane'].replace(['normal_pink','pale_pink','bright_pink','bright_red','pale_cyanotic','dark_cyanotic'],[0,1,2,3,4,5],inplace=True)
Test['mucous_membrane'].replace(['normal_pink','pale_pink','bright_pink','bright_red','pale_cyanotic','dark_cyanotic'],[0,1,2,3,4,5],inplace=True)
Test['peristalsis'].replace(['absent','normal','hypomotile','hypermotile'],[0,1,2,3],inplace=True)
Test['abdominal_distention'].replace(['none','slight','moderate','severe'],[0,1,2,3],inplace=True)
Test['nasogastric_tube'].replace(['none','slight','significant'],[0,1,2],inplace=True)
Test['nasogastric_reflux'].replace(['none','slight','less_1_liter','more_1_liter'],[0,1,2,3],inplace=True)
Test['rectal_exam_feces'].replace(['absent','normal','decreased','increased','serosanguious'],[0,1,2,3,4],inplace=True)
Test['abdomen'].replace(['normal','firm','distend_small','distend_large','other'],[0,1,2,3,4],inplace=True)
Test['abdomo_appearance'].replace(['clear','cloudy','serosanguious'],[0,1,2],inplace=True)
Test['surgical_lesion'].replace(['no','yes'],[0,1],inplace=True)
Test['cp_data'].replace(['no','yes'],[0,1],inplace=True)
Test['age'].replace(['adult','young'],[1,0],inplace=True)

# %%
Test = Test.drop(columns=['hospital_number'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 Test = Test.drop(columns=['hospital_number'])
#
# File /usr/lib/python3/dist-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File /usr/lib/python3/dist-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File /usr/lib/python3/dist-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File /usr/lib/python3/dist-packages/pandas/core/indexes/base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['hospital_number'] not found in axis"

# %%
Test.head()
# Out:
#      id  surgery  age  rectal_temp  pulse  respiratory_rate  \
# 0  1235        0    1         38.6   40.0              20.0
# 1  1236        1    1         38.2  112.0              48.0
# 2  1237        1    1         37.7   66.0              12.0
# 6  1241        1    1         40.8  114.0              36.0
# 8  1243        1    1         38.3   66.0              12.0
#
#    temp_of_extremities  peripheral_pulse  mucous_membrane  \
# 0                    2                 2                0
# 1                    1                 1                2
# 2                    1                 2                3
# 6                    0                 1                5
# 8                    1                 1                1
#
#    capillary_refill_time  ...  abdomen  packed_cell_volume  total_protein  \
# 0                      0  ...        2                42.0            7.5
# 1                      2  ...        2                44.0            6.0
# 2                      0  ...        2                31.5            6.0
# 6                      2  ...        2                40.0            8.6
# 8                      0  ...        3                39.0            6.0
#
#    abdomo_appearance  abdomo_protein  surgical_lesion  lesion_1  lesion_2  \
# 0                  0             2.3                0         0         0
# 1                  2             2.6                0      2208         0
# 2                  1             1.6                1      2205         0
# 6                  2             2.6                1      2209         0
# 8                  2             3.4                1      4205         0
#
#    lesion_3  cp_data
# 0         0        0
# 1         0        1
# 2         0        1
# 6         0        1
# 8         0        0
#
# [5 rows x 27 columns]

# %%
import matplotlib.pyplot as plt

# %%
print("Columns in train:", Train.columns.tolist())

if 'outcome' in Train.columns:
    train_features = Train.drop(columns=['outcome'])
else:
    train_features = Train.copy()

int_columns = train_features.select_dtypes(include=['int', 'int32', 'int64']).columns

num_features = len(int_columns)
cols = 2
rows = (num_features + cols - 1) // cols

plt.figure(figsize=(14, 4 * rows))

for i, col in enumerate(int_columns, 1):
    plt.subplot(rows, cols, i)

    if col in Test.columns:
        train_vals = Train[col].dropna()
        test_vals = Test[col].dropna()

        plt.hist(train_vals, bins=30, alpha=0.5, color='blue', label='Train', density=True)
        plt.hist(test_vals, bins=30, alpha=0.5, color='red', label='Test', density=True)
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Density')
        plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Columns in train: ['id', 'surgery', 'age', 'rectal_temp', 'pulse', 'respiratory_rate', 'temp_of_extremities', 'peripheral_pulse', 'mucous_membrane', 'capillary_refill_time', 'pain', 'peristalsis', 'abdominal_distention', 'nasogastric_tube', 'nasogastric_reflux', 'nasogastric_reflux_ph', 'rectal_exam_feces', 'abdomen', 'packed_cell_volume', 'total_protein', 'abdomo_appearance', 'abdomo_protein', 'surgical_lesion', 'lesion_1', 'lesion_2', 'lesion_3', 'cp_data', 'outcome']

# %%
Train['lesion_2'].replace(['3111','3112'],[1,2],inplace=True)
Train['lesion_3'].replace(['2209'],[1],inplace=True)

# %%
Test['lesion_2'].replace(['3111','3112'],[1,2],inplace=True)
Test['lesion_3'].replace(['2209'],[1],inplace=True)

# %%
Train = Train.drop(columns=['lesion_1'])

# %%
Test = Test.drop(columns=['lesion_1'])

# %%
Train = Train.drop(columns=['id'])

# %%
Test.head()
# Out:
#      id  surgery  age  rectal_temp  pulse  respiratory_rate  \
# 0  1235        0    1         38.6   40.0              20.0
# 1  1236        1    1         38.2  112.0              48.0
# 2  1237        1    1         37.7   66.0              12.0
# 6  1241        1    1         40.8  114.0              36.0
# 8  1243        1    1         38.3   66.0              12.0
#
#    temp_of_extremities  peripheral_pulse  mucous_membrane  \
# 0                    2                 2                0
# 1                    1                 1                2
# 2                    1                 2                3
# 6                    0                 1                5
# 8                    1                 1                1
#
#    capillary_refill_time  ...  rectal_exam_feces  abdomen  packed_cell_volume  \
# 0                      0  ...                  1        2                42.0
# 1                      2  ...                  2        2                44.0
# 2                      0  ...                  1        2                31.5
# 6                      2  ...                  1        2                40.0
# 8                      0  ...                  2        3                39.0
#
#    total_protein  abdomo_appearance  abdomo_protein  surgical_lesion  \
# 0            7.5                  0             2.3                0
# 1            6.0                  2             2.6                0
# 2            6.0                  1             1.6                1
# 6            8.6                  2             2.6                1
# 8            6.0                  2             3.4                1
#
#    lesion_2  lesion_3  cp_data
# 0         0         0        0
# 1         0         0        1
# 2         0         0        1
# 6         0         0        1
# 8         0         0        0
#
# [5 rows x 26 columns]

# %%
Train.head()
# Out:
#    surgery  age  rectal_temp  pulse  respiratory_rate  temp_of_extremities  \
# 0        1    1         38.1  132.0              24.0                    1
# 1        1    1         37.5   88.0              12.0                    1
# 3        1    1         37.1   72.0              30.0                    0
# 4        0    1         38.0   52.0              48.0                    2
# 5        0    1         38.1   56.0              32.0                    2
#
#    peripheral_pulse  mucous_membrane  capillary_refill_time  pain  ...  \
# 0                 1                5                      2     4  ...
# 1                 2                4                      2     0  ...
# 3                 1                1                      2     0  ...
# 4                 2                0                      0     1  ...
# 5                 2                2                      0     4  ...
#
#    abdomen  packed_cell_volume  total_protein  abdomo_appearance  \
# 0        2                57.0            8.5                  2
# 1        2                33.0           64.0                  2
# 3        2                53.0            7.0                  1
# 4        0                47.0            7.3                  1
# 5        1                49.0            8.0                  1
#
#    abdomo_protein  surgical_lesion  lesion_2  lesion_3  cp_data  outcome
# 0             3.4                1         0         0        0        0
# 1             2.0                1         0         0        0        2
# 3             3.9                1         0         0        1        1
# 4             2.6                0         0         0        1        1
# 5             2.8                0         0         0        1        1
#
# [5 rows x 26 columns]

# %%
#Standardizing #

mean = Train['pulse'].mean()
std = Train['pulse'].std()

Train['pulse'] = (Train['pulse'] - mean) / std
Test['pulse'] = (Test['pulse'] - mean) / std

mean1 = Train['rectal_temp'].mean()
std1 = Train['rectal_temp'].std()

Train['rectal_temp'] = (Train['rectal_temp'] - mean1) / std1
Test['rectal_temp'] = (Test['rectal_temp'] - mean1) / std1


mean2 = Train['respiratory_rate'].mean()
std2 = Train['respiratory_rate'].std()

Train['respiratory_rate'] = (Train['respiratory_rate'] - mean2) / std2
Test['respiratory_rate'] = (Test['respiratory_rate'] - mean2) / std2

mean3 = Train['nasogastric_reflux_ph'].mean()
std3 = Train['nasogastric_reflux_ph'].std()

Train['nasogastric_reflux_ph'] = (Train['nasogastric_reflux_ph'] - mean3) / std3
Test['nasogastric_reflux_ph'] = (Test['nasogastric_reflux_ph'] - mean3) / std3

mean4 = Train['packed_cell_volume'].mean()
std4 = Train['packed_cell_volume'].std()

Train['packed_cell_volume'] = (Train['packed_cell_volume'] - mean4) / std4
Test['packed_cell_volume'] = (Test['packed_cell_volume'] - mean4) / std4


mean5 = Train['total_protein'].mean()
std5 = Train['total_protein'].std()

Train['total_protein'] = (Train['total_protein'] - mean5) / std5
Test['total_protein'] = (Test['total_protein'] - mean5) / std5


mean6 = Train['abdomo_protein'].mean()
std6 = Train['abdomo_protein'].std()

Train['abdomo_protein'] = (Train['abdomo_protein'] - mean6) / std6
Test['abdomo_protein'] = (Test['abdomo_protein'] - mean6) / std6

# %%
import sys
sys.path.append('/home/fvalens11/sklearn-env/lib/python3.12/site-packages')

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

X_train = Train.drop(columns=['outcome'])
y_train = Train['outcome']

X_test = Test.drop(columns=['id'])

label_encoder = LabelEncoder()

for column in X_train.select_dtypes(include=['object']).columns:
    X_train[column] = label_encoder.fit_transform(X_train[column])
    X_test[column] = label_encoder.transform(X_test[column])

model = RandomForestClassifier(n_estimators=100, random_state=42)

model.fit(X_train, y_train)

predictions = model.predict(X_test)

result = pd.DataFrame({
    'id': Test['id'],
    'outcome': predictions
})

outcome_map = {0: 'died', 1: 'lived', 2: 'euthanized'}
result['outcome'] = result['outcome'].map(outcome_map)

print(result)

result.to_csv('predictions.csv', index=False)
# Out:
#        id     outcome
# 0    1235       lived
# 1    1236        died
# 2    1237       lived
# 6    1241        died
# 8    1243       lived
# ..    ...         ...
# 815  2050  euthanized
# 816  2051        died
# 817  2052        died
# 818  2053  euthanized
# 820  2055  euthanized
#
# [500 rows x 2 columns]

# %%
score = pd.read_csv('sample_submission.csv')

# %%
score.tail()
# Out:
#        id outcome
# 819  2054   lived
# 820  2055   lived
# 821  2056   lived
# 822  2057   lived
# 823  2058   lived

# %%
my_score = pd.read_csv('predictions.csv')

# %%
my_score.tail()
# Out:
#        id     outcome
# 495  2050  euthanized
# 496  2051        died
# 497  2052        died
# 498  2053  euthanized
# 499  2055  euthanized

# %%
import pandas as pd
from sklearn.metrics import f1_score


merged = pd.merge(my_score, score, on='id', suffixes=('_pred', '_true'))

y_pred = merged['outcome_pred']
y_true = merged['outcome_true']

f1 = f1_score(y_true, y_pred, average='macro')  # you could also try 'weighted'

print(f"F1 Score: {f1:.4f}")
# Out:
# F1 Score: 0.2156

# %%
import pandas as pd
from sklearn.metrics import f1_score
import numpy as np

merged = pd.merge(my_score, score, on='id', suffixes=('_pred', '_true'))

y_pred = merged['outcome_pred']
y_true = merged['outcome_true']

class_weights = {
    'lived': 2.0,
    'died': 1.0,
    'euthanized': 1.0
}

classes = ['lived', 'died', 'euthanized']

f1_scores = f1_score(y_true, y_pred, average=None, labels=classes)


weights = np.array([class_weights[cls] for cls in classes])
weighted_f1 = np.sum(f1_scores * weights) / np.sum(weights)

for cls, score in zip(classes, f1_scores):
    print(f"F1 Score for {cls}: {score:.4f}")
print(f"\nWeighted F1 Score (with emphasis on 'lived'): {weighted_f1:.4f}")
# Out:
# F1 Score for lived: 0.6468
# F1 Score for died: 0.0000
# F1 Score for euthanized: 0.0000
#
# Weighted F1 Score (with emphasis on 'lived'): 0.3234
